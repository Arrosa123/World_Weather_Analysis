# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID           City Country  Max Temp Current Description      Lat  \
# 0        6        Mogotes      CO     75.92     overcast clouds   6.4756
# 1       11     Port Blair      IN     77.04                mist  11.6667
# 2       15  Makakilo City      US     75.61           clear sky  21.3469
# 3       16        Rikitea      PF     79.07           clear sky -23.1203
# 4       17         Lompoc      US     83.12           clear sky  34.6391
#
#         Lng                                         Hotel Name
# 0  -72.9705                         Hostal Hacienda Villarreal
# 1   92.7500  Welcomhotel By ITC Hotels, Bay Island, Port Blair
# 2 -158.0858                     Marriott's Ko Olina Beach Club
# 3 -134.9692                                    People ThankYou
# 4 -120.4579           Holiday Inn Express Lompoc, an IHG Hotel

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>

"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]
# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Grab the first hotel from the results and store the name.
mexico_vacation_df = vacation_df.loc[(vacation_df["Country"] == "US")]
mexico_vacation_df.dropna()
# Out:
#      City_ID           City Country  Max Temp Current Description      Lat  \
# 2         15  Makakilo City      US     75.61           clear sky  21.3469
# 4         17         Lompoc      US     83.12           clear sky  34.6391
# 24        98   San Patricio      US     77.09           clear sky  28.0170
# 28       104  Pacific Grove      US     76.30           clear sky  36.6177
# 34       125       Key West      US     77.00       broken clouds  24.5557
# 41       150        Kahului      US     75.85          few clouds  20.8947
# 46       176           Hilo      US     75.61       broken clouds  19.7297
# 72       265          Mango      US     79.12    scattered clouds  27.9797
# 79       290      Key Largo      US     82.02          few clouds  25.0865
# 83       302   Port Hueneme      US     86.32           clear sky  34.1478
# 127      473      Ewa Beach      US     77.02           clear sky  21.3156
# 196      673  Half Moon Bay      US     75.45           clear sky  37.4636
#
#           Lng                                   Hotel Name
# 2   -158.0858               Marriott's Ko Olina Beach Club
# 4   -120.4579     Holiday Inn Express Lompoc, an IHG Hotel
# 24   -97.5169                           Motel 6 Sinton, TX
# 28  -121.9166                             Lovers Point Inn
# 34   -81.7826  Fairfield Inn & Suites by Marriott Key West
# 41  -156.4700                           Maui Seaside Hotel
# 46  -155.0900                          Hilo Hawaiian Hotel
# 72   -82.3065         Hilton Garden Inn Tampa East/Brandon
# 79   -80.4473                        Bayside Inn Key Largo
# 83  -119.1951           Hampton Inn Channel Islands Harbor
# 127 -158.0072                          Uncle Junior Robert
# 196 -122.4286              The Ritz-Carlton, Half Moon Bay

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
vacation_start = vacation_df.loc[vacation_df['City'] == 'Lompoc']
vacation_end = vacation_df.loc[vacation_df['City'] == 'Lompoc']
vacation_stop1 = vacation_df.loc[vacation_df['City'] == 'San Patricio']
vacation_stop2 = vacation_df.loc[vacation_df['City'] == 'Pacific Grove']
vacation_stop3 = vacation_df.loc[vacation_df['City'] == 'Key West']

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = tuple(vacation_start[["Lat", "Lng"]].to_numpy()[0])
end = tuple(vacation_end[["Lat", "Lng"]].to_numpy()[0])
stop1 = tuple(vacation_stop1[["Lat", "Lng"]].to_numpy()[0])
stop2 = tuple(vacation_stop2[["Lat", "Lng"]].to_numpy()[0])
stop3 = tuple(vacation_stop3[["Lat", "Lng"]].to_numpy()[0])

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
start = start
end = end
waypoints = [stop1, stop2, stop3]
directions = gmaps.directions_layer(start, end, waypoints=waypoints, travel_mode='DRIVING')
fig.add_layer(directions)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3, vacation_end],ignore_index=True)
itinerary_df
# Out:
#    City_ID           City Country  Max Temp Current Description      Lat  \
# 0       17         Lompoc      US     83.12           clear sky  34.6391
# 1       98   San Patricio      US     77.09           clear sky  28.0170
# 2      104  Pacific Grove      US     76.30           clear sky  36.6177
# 3      125       Key West      US     77.00       broken clouds  24.5557
# 4       17         Lompoc      US     83.12           clear sky  34.6391
#
#         Lng                                   Hotel Name
# 0 -120.4579     Holiday Inn Express Lompoc, an IHG Hotel
# 1  -97.5169                           Motel 6 Sinton, TX
# 2 -121.9166                             Lovers Point Inn
# 3  -81.7826  Fairfield Inn & Suites by Marriott Key West
# 4 -120.4579     Holiday Inn Express Lompoc, an IHG Hotel

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
